# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.python.ops import math_ops
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.patches import ConnectionPatch
import warnings

import pickle

from sklearn.neighbors import KernelDensity
from sklearn.ensemble import RandomForestClassifier

from tqdm import tqdm
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# Bad key "text.kerning_factor" on line 4 in
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# # Experiment Parameters

# %%
plot_step = 0.01
width = 4
n = 50000
acc_thresh = 0.95
epochs = 50

train_new = True

# %% [markdown]
# # Data Generation
# ## Function

# %%
def generate_XOR(n):
    '''
    means = np.array([[-1, -1], [1, 1], [-1, 1], [1, -1]])
    X = np.concatenate([np.random.multivariate_normal(mean, 0.1 * np.eye(len(mean)),
                                                 size=int(n / 4)) for mean in means])

    y = np.concatenate([np.ones(int(n / 4)) * int(idx < 2) for idx in range(len(means))])
    '''
    X = np.concatenate([np.random.uniform(-1, 1, size = (n, 1)), np.random.uniform(-1, 1, size = (n, 1))], axis = 1)
    y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0).astype('int')
    
    random_indices_order = list(range(len(X)))
    np.random.shuffle(random_indices_order)
    
    return X[random_indices_order], np.array(y[random_indices_order]).astype('int')

# %% [markdown]
# ## Training Data

# %%
X, y = generate_XOR(n = n)

# %% [markdown]
# ## Grid Generation

# %%
x_min, x_max = X[:, 0].min() - 0.25, X[:, 0].max() + 0.25
y_min, y_max = X[:, 1].min() - 0.25, X[:, 1].max() + 0.25
xx, yy = np.meshgrid(np.arange(x_min, x_max, (x_max - x_min) / 100),
                      np.arange(y_min, y_max, (y_max - y_min) / 100))
zz = np.logical_xor(xx > 0, yy < 0)

# %% [markdown]
# # Construct & Train Network

# %%
class Uni(keras.layers.Layer):

    def call(self, inputs):
        z_coef, z = inputs
        return z_coef / (1 + keras.backend.exp(-10*z))
    
def get_network():
    inp = keras.Input(shape=np.shape(X)[1:])
    x = keras.layers.Dense(width, activation="relu", kernel_initializer = "he_normal")(inp)
    z = keras.layers.Dense(2, kernel_initializer = "he_normal")(x)    
    z_coef = keras.layers.Dense(2, activation = "sigmoid", kernel_initializer = "he_normal")(x)    
    p_vals = Uni()([z_coef, z])
    out = p_vals / math_ops.reduce_sum(p_vals, axis=1, keepdims=True)
    network = keras.Model(inp, [out])
    network.compile(loss = 'categorical_crossentropy', optimizer = keras.optimizers.Adam(5e-4), metrics = ['acc'])
    return network

# %%
'''
def get_network():
    network = keras.Sequential()
    network.add(keras.layers.Dense(width, input_shape = np.shape(X)[1:], activation = 'relu', use_bias=True, kernel_initializer = 'he_normal'))
    network.add(keras.layers.Dense(1, activation = 'sigmoid', use_bias=True, kernel_initializer = 'he_normal'))
    network.compile(loss = 'binary_crossentropy', optimizer = keras.optimizers.SGD(1e-2, momentum = 0.9), metrics = ['acc'])
    return network
'''
# Out:
# "\ndef get_network():\n    network = keras.Sequential()\n    network.add(keras.layers.Dense(width, input_shape = np.shape(X)[1:], activation = 'relu', use_bias=True, kernel_initializer = 'he_normal'))\n    network.add(keras.layers.Dense(1, activation = 'sigmoid', use_bias=True, kernel_initializer = 'he_normal'))\n    network.compile(loss = 'binary_crossentropy', optimizer = keras.optimizers.SGD(1e-2, momentum = 0.9), metrics = ['acc'])\n    return network\n"

# %%
if train_new:
    acc = 0
    while acc < acc_thresh:
      network = get_network()
      network.fit(
          X, 
          keras.utils.to_categorical(y), 
          epochs = epochs, 
          verbose = True,
          batch_size = 256,
          callbacks = [keras.callbacks.ModelCheckpoint("best_weights.h5", monitor = "loss")]
      )
      network.load_weights("best_weights.h5")
      acc = network.evaluate(X, keras.utils.to_categorical(y), verbose = False)[1]
      if acc >= acc_thresh:
        print("Done training. Acc = {:0.2f} > Acc Thresh = {:0.2f}.".format(acc, acc_thresh))
      else:
        print("Training New Network since Acc = {:0.2f} < Acc Thresh = {:0.2f}...".format(acc, acc_thresh))
      network.save_weights("best_weights.h5")
else:
    network = get_network()
    network.load_weights("best_weights.h5")
# Out:
# Train on 50000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 1s 16us/sample - loss: 1.6244 - acc: 0.4872
# Epoch 2/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.7664 - acc: 0.5333
# Epoch 3/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.5535 - acc: 0.6987
# Epoch 4/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.4907 - acc: 0.7609
# Epoch 5/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.4570 - acc: 0.7612
# Epoch 6/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.4289 - acc: 0.7747
# Epoch 7/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.4013 - acc: 0.8020
# Epoch 8/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.3734 - acc: 0.8352
# Epoch 9/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.3445 - acc: 0.8698
# Epoch 10/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.3151 - acc: 0.9003
# Epoch 11/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.2863 - acc: 0.9265
# Epoch 12/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.2592 - acc: 0.9447
# Epoch 13/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.2338 - acc: 0.9557
# Epoch 14/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.2106 - acc: 0.9621
# Epoch 15/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1900 - acc: 0.9662
# Epoch 16/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1722 - acc: 0.9694
# Epoch 17/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1565 - acc: 0.9724
# Epoch 18/50
# 50000/50000 [==============================] - 1s 10us/sample - loss: 0.1425 - acc: 0.9766
# Epoch 19/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1301 - acc: 0.9797
# Epoch 20/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1190 - acc: 0.9827
# Epoch 21/50
# 50000/50000 [==============================] - 1s 10us/sample - loss: 0.1094 - acc: 0.9858
# Epoch 22/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1012 - acc: 0.9876
# Epoch 23/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0943 - acc: 0.9888
# Epoch 24/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0884 - acc: 0.9894
# Epoch 25/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0833 - acc: 0.9897
# Epoch 26/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0788 - acc: 0.9907
# Epoch 27/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0748 - acc: 0.9912
# Epoch 28/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0711 - acc: 0.9913
# Epoch 29/50
# 50000/50000 [==============================] - 1s 10us/sample - loss: 0.0679 - acc: 0.9912
# Epoch 30/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0649 - acc: 0.9915
# Epoch 31/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0623 - acc: 0.9919
# Epoch 32/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0598 - acc: 0.9917
# Epoch 33/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0575 - acc: 0.9918
# Epoch 34/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0554 - acc: 0.9920
# Epoch 35/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0535 - acc: 0.9922
# Epoch 36/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0516 - acc: 0.9923
# Epoch 37/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0499 - acc: 0.9921
# Epoch 38/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0483 - acc: 0.9922
# Epoch 39/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0468 - acc: 0.9927
# Epoch 40/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0453 - acc: 0.9929
# Epoch 41/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0443 - acc: 0.9930
# Epoch 42/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0433 - acc: 0.9928
# Epoch 43/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0446 - acc: 0.9931
# Epoch 44/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0481 - acc: 0.9930
# Epoch 45/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0514 - acc: 0.9928
# Epoch 46/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0571 - acc: 0.9926
# Epoch 47/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0654 - acc: 0.9922
# Epoch 48/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.0757 - acc: 0.9915
# Epoch 49/50
# 50000/50000 [==============================] - 1s 10us/sample - loss: 0.0846 - acc: 0.9910
# Epoch 50/50
# 50000/50000 [==============================] - 0s 10us/sample - loss: 0.1079 - acc: 0.9898
# Done training. Acc = 0.99 > Acc Thresh = 0.95.

# %% [markdown]
# ## Polytope Pyramid

# %%
input_weights, ultimate_weights = [network.layers[i].get_weights()[0] for i in {1, 2}]
input_bias, ultimate_bias = [network.layers[i].get_weights()[1] for i in {1, 2}]

second_layer_preactivations = np.matmul(X, input_weights) + input_bias 
second_layer_binary_activations = (second_layer_preactivations > 0).astype('int')
second_layer_activations = second_layer_preactivations * second_layer_binary_activations

ultimate_preactivations = np.matmul(second_layer_activations, ultimate_weights) + ultimate_bias
ultimate_binary_activations = (ultimate_preactivations > 0).astype('int')
ultimate_activations = ultimate_preactivations * ultimate_binary_activations

output_activations = network.predict(X)

output_binary_activations = (output_activations > 0.5).astype('int')

polytope_memberships = np.concatenate([second_layer_binary_activations, ultimate_binary_activations, output_binary_activations], axis = 1)
polytope_ids = np.matmul(polytope_memberships, 2 ** np.arange(0, np.shape(polytope_memberships)[1]))

polytope_id_to_posterior = {}
for polytope_id in np.unique(polytope_ids):
    posterior = []
    for y_val in np.unique(y):
        num_examples_of_polytope_of_class = len(np.where((polytope_ids == polytope_id) & (y == y_val))[0])
        posterior.append(num_examples_of_polytope_of_class)
    posterior = np.array(posterior) / np.sum(posterior)
    polytope_id_to_posterior[polytope_id] = posterior

# %%
input_weights, ultimate_weights = [network.layers[i].get_weights()[0] for i in {1, 2}]
input_bias, ultimate_bias = [network.layers[i].get_weights()[1] for i in {1, 2}]

second_layer_preactivations = np.matmul(np.c_[xx.ravel(), yy.ravel()], input_weights) + input_bias 
second_layer_binary_activations = (second_layer_preactivations > 0).astype('int')
second_layer_activations = second_layer_preactivations * second_layer_binary_activations

ultimate_preactivations = np.matmul(second_layer_activations, ultimate_weights) + ultimate_bias
ultimate_binary_activations = (ultimate_preactivations > 0).astype('int')
ultimate_activations = ultimate_preactivations * ultimate_binary_activations

output_activations = network.predict(np.c_[xx.ravel(), yy.ravel()])

output_binary_activations = (output_activations > 0.5).astype('int')

polytope_memberships = np.concatenate([second_layer_binary_activations, ultimate_binary_activations, output_binary_activations], axis = 1)
polytope_ids = np.matmul(polytope_memberships, 2 ** np.arange(0, np.shape(polytope_memberships)[1]))

# %%
'''
figs, axs = plt.subplots(2, width, figsize = (6 * width, 6 * 2))
plt.subplots_adjust(hspace=0.5)
figs.text(0.5, 0.04, '', ha='center')
figs.set_facecolor('white')

for i, ax in enumerate(axs.flat):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    if int(i // width) == 0:
        ax.set_ylabel('Base Polytopes', fontsize = 36)
    elif int(i // width) == 1:
        ax.set_ylabel('Final Polytopes', fontsize = 36)
    ax.label_outer()
    ax.set_facecolor('white')
    
    for side in {"right", "left", "top", "bottom"}:
        ax.spines[side].set_visible(False)
        
for second_node in range(width):
    for multiplier in [-1, 1]:
      axs[0][second_node].contour(xx, 
                                yy, 
                                second_layer_activations[:, second_node].reshape(xx.shape) + multiplier * 1e-6, 
                                levels=[0], 
                                colors="#d95f02",
                                vmin = -1, 
                                vmax = 0,
                                linewidths = 6)
    axs[0][second_node].pcolormesh(xx, 
                          yy, 
                          second_layer_activations[:, second_node].reshape(xx.shape), 
                          cmap="Greens", 
                          vmin = 0, 
                          vmax = np.max(second_layer_activations)
                          )

for second_node in range(width):
  second_w_sign = np.sign(ultimate_weights[second_node])
  second_node_contributes = np.abs(ultimate_weights[second_node]) > 1e-6

  if second_node_contributes:
    con = ConnectionPatch(axesA=axs[0][second_node], 
                        axesB=axs[1][int(width / 2)], 
                        xyA = [0, np.min(yy)],
                        xyB = [0, np.max(yy)],
                        coordsA="data", 
                        coordsB="data", 
                        color="green" if ultimate_weights[second_node] > 0 else "purple", 
                        lw=6 * np.abs(ultimate_weights[second_node]) / np.max(np.abs(ultimate_weights)))
    axs[1][int(width / 2)].add_artist(con)

for second_node in range(width):
    for multiplier in [-1, 1]:
      axs[1][int(width / 2)].contour(xx, 
                                       yy, 
                                       second_layer_preactivations[:, second_node].reshape(xx.shape) + multiplier * 1e-6, 
                                       levels=[0], 
                                       cmap="Greens" if ultimate_weights[second_node] > 0 else "Purples",
                                       vmin = -1, 
                                       vmax = 0,
                                       linewidths = 6 * np.abs(ultimate_weights[second_node]) / np.max(np.abs(ultimate_weights))
                                    )

axs[1][int(width / 2)].pcolormesh(xx, 
                               yy, 
                               ultimate_preactivations.reshape(xx.shape), 
                               cmap="PRGn", 
                               vmin = -np.max(np.abs(ultimate_preactivations)), 
                               vmax = np.max(np.abs(ultimate_preactivations)))

for multiplier in [-1, 1]:
  axs[1][int(width / 2)].contour(xx, 
                               yy, 
                               ultimate_preactivations.reshape(xx.shape) + multiplier * 1e-6, 
                               colors="#d95f02", 
                               vmin = -1, 
                               vmax = 0,
                               levels=[0],
                               linewidths=6,
                               zorder = 1e16)
'''
# Out:
# '\nfigs, axs = plt.subplots(2, width, figsize = (6 * width, 6 * 2))\nplt.subplots_adjust(hspace=0.5)\nfigs.text(0.5, 0.04, \'\', ha=\'center\')\nfigs.set_facecolor(\'white\')\n\nfor i, ax in enumerate(axs.flat):\n    ax.set_xticks([])\n    ax.set_yticks([])\n    ax.set_xlabel(\'\')\n    if int(i // width) == 0:\n        ax.set_ylabel(\'Base Polytopes\', fontsize = 36)\n    elif int(i // width) == 1:\n        ax.set_ylabel(\'Final Polytopes\', fontsize = 36)\n    ax.label_outer()\n    ax.set_facecolor(\'white\')\n    \n    for side in {"right", "left", "top", "bottom"}:\n        ax.spines[side].set_visible(False)\n        \nfor second_node in range(width):\n    for multiplier in [-1, 1]:\n      axs[0][second_node].contour(xx, \n                                yy, \n                                second_layer_activations[:, second_node].reshape(xx.shape) + multiplier * 1e-6, \n                                levels=[0], \n                                colors="#d95f02",\n                                vmin = -1, \n                                vmax = 0,\n                                linewidths = 6)\n    axs[0][second_node].pcolormesh(xx, \n                          yy, \n                          second_layer_activations[:, second_node].reshape(xx.shape), \n                          cmap="Greens", \n                          vmin = 0, \n                          vmax = np.max(second_layer_activations)\n                          )\n\nfor second_node in range(width):\n  second_w_sign = np.sign(ultimate_weights[second_node])\n  second_node_contributes = np.abs(ultimate_weights[second_node]) > 1e-6\n\n  if second_node_contributes:\n    con = ConnectionPatch(axesA=axs[0][second_node], \n                        axesB=axs[1][int(width / 2)], \n                        xyA = [0, np.min(yy)],\n                        xyB = [0, np.max(yy)],\n                        coordsA="data", \n                        coordsB="data", \n                        color="green" if ultimate_weights[second_node] > 0 else "purple", \n                        lw=6 * np.abs(ultimate_weights[second_node]) / np.max(np.abs(ultimate_weights)))\n    axs[1][int(width / 2)].add_artist(con)\n\nfor second_node in range(width):\n    for multiplier in [-1, 1]:\n      axs[1][int(width / 2)].contour(xx, \n                                       yy, \n                                       second_layer_preactivations[:, second_node].reshape(xx.shape) + multiplier * 1e-6, \n                                       levels=[0], \n                                       cmap="Greens" if ultimate_weights[second_node] > 0 else "Purples",\n                                       vmin = -1, \n                                       vmax = 0,\n                                       linewidths = 6 * np.abs(ultimate_weights[second_node]) / np.max(np.abs(ultimate_weights))\n                                    )\n\naxs[1][int(width / 2)].pcolormesh(xx, \n                               yy, \n                               ultimate_preactivations.reshape(xx.shape), \n                               cmap="PRGn", \n                               vmin = -np.max(np.abs(ultimate_preactivations)), \n                               vmax = np.max(np.abs(ultimate_preactivations)))\n\nfor multiplier in [-1, 1]:\n  axs[1][int(width / 2)].contour(xx, \n                               yy, \n                               ultimate_preactivations.reshape(xx.shape) + multiplier * 1e-6, \n                               colors="#d95f02", \n                               vmin = -1, \n                               vmax = 0,\n                               levels=[0],\n                               linewidths=6,\n                               zorder = 1e16)\n'

# %%
def pdf(x):
    '''
    mu01, mu02, mu11, mu12 = [[-1, -1], [1, 1], [-1, 1], [1, -1]]
    cov = 0.25 * np.eye(2)
    inv_cov = np.linalg.inv(cov) 

    p0 = (
        np.exp(-(x - mu01)@inv_cov@(x-mu01).T) 
        + np.exp(-(x - mu02)@inv_cov@(x-mu02).T)
    )/(2*np.pi*np.sqrt(np.linalg.det(cov)))

    p1 = (
        np.exp(-(x - mu11)@inv_cov@(x-mu11).T) 
        + np.exp(-(x - mu12)@inv_cov@(x-mu12).T)
    )/(2*np.pi*np.sqrt(np.linalg.det(cov)))
    '''
    return int(np.sign(x[0]) * np.sign(x[1]) == -1)
    #return p0/(p0+p1)

true_posterior = [pdf(x) for x in tqdm(np.c_[xx.ravel(), yy.ravel()])]
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 188475.86it/s]

# %%
if train_new:
    acc = 0
    while acc < acc_thresh:
      rfc = RandomForestClassifier(n_estimators = 2, 
                                   max_depth = 4)

      rfc.fit(X, y)
      y_hat = rfc.predict(X)
      acc = np.mean(y_hat == y)
      if acc >= acc_thresh:
        print("Done training. Acc = {:0.2f} > Acc Thresh = {:0.2f}.".format(acc, acc_thresh))
      else:
        print("Training New Forest since Acc = {:0.2f} < Acc Thresh = {:0.2f}...".format(acc, acc_thresh))
    pickle.dump(rfc, open('best_forest.pkl', 'wb'))
else:
    rfc = pickle.load(open('best_forest.pkl', 'rb'))
# Out:
# Done training. Acc = 1.00 > Acc Thresh = 0.95.

# %%
figs, axs = plt.subplots(4, 3, figsize = (12 * 3, 12 * 4))
plt.subplots_adjust(hspace=0.5)
figs.text(0.5, 0.04, '', ha='center')
figs.set_facecolor('white')

for i, ax in enumerate(axs.flat):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.label_outer()
    ax.set_facecolor('white')
    
    for side in {"right", "left", "top", "bottom"}:
        ax.spines[side].set_visible(False)
        
for i in range(3):
    axs[i][0].set_ylim((np.min(yy), np.max(yy)))
    axs[i][0].set_xlim((np.min(xx), np.max(xx)))
        
# Plot the training points
axs[0][0].scatter(X[:, 0], X[:, 1], c=['green' if y[i] == 1 else 'purple' for i in range(len(y))],
          s=15, edgecolor = 'black', alpha = .25)
axs[0][0].set_title("Data Colored\nBy True Class", fontsize = 36)

axs[0][1].set_title("True Class\n1 Posterior", fontsize = 36)
axs[0][1].pcolormesh(xx, 
                               yy, 
                               np.array(true_posterior).reshape(xx.shape), 
                               cmap="PRGn", 
                               vmin = 0, 
                               vmax = 1)


axs[0][2].set_title("Optimal Partition", fontsize = 36)
c = np.array([int(np.sign(np.prod(ra)) == 1) for ra in np.c_[xx.ravel(), yy.ravel()]])
#c = np.array([np.sum((ra > 0).astype('int') * 2 ** np.arange(0, len(ra))) for ra in np.c_[xx.ravel(), yy.ravel()]])
axs[0][2].contourf(xx, yy, c.reshape(xx.shape), cmap = "tab20", vmin = -1, vmax = 1)

y_hat = np.argmax(network.predict(X), axis = 1)
axs[1][0].scatter(X[:, 0], X[:, 1], c=['green' if y_hat[i] == 1 else 'purple' for i in range(len(y))],
          s=15, edgecolor = 'black', alpha = .25)
axs[1][0].set_title("Data Colored\nBy Estimated Class", fontsize = 36)
axs[1][0].set_ylabel("Uniform\nNetwork", fontsize = 36)

axs[1][1].set_title("Estimated Class\n1 Posterior", fontsize = 36)
    
    
estimated_class_1_posterior = network.predict(np.c_[xx.ravel(), yy.ravel()])[:, 1]  
axs[1][1].pcolormesh(xx, 
                               yy, 
                               estimated_class_1_posterior.reshape(xx.shape), 
                               cmap="PRGn", 
                               vmin = 0, 
                               vmax = 1)

axs[1][2].contourf(xx, yy, polytope_ids.reshape(xx.shape), cmap = "tab20", levels = len(np.unique(polytope_ids)))
axs[1][2].set_title("Estimated Partition", fontsize = 36)

y_proba = np.array([polytope_id_to_posterior[polytope_id] if polytope_id in list(polytope_id_to_posterior.keys()) else [0.5, 0.5] for polytope_id in polytope_ids])
axs[2][0].scatter(X[:, 0], X[:, 1], c=['green' if y_hat[i] == 1 else 'purple' for i in range(len(y))],
          s=15, edgecolor = 'black', alpha = .25)
axs[2][0].set_title("Data Colored\nBy Estimated Class", fontsize = 36)
axs[2][0].set_ylabel("Uncertainty\nNetwork", fontsize = 36)

axs[2][1].set_title("Estimated Class\n1 Posterior", fontsize = 36)
    
    
axs[2][1].pcolormesh(xx, 
                               yy, 
                               y_proba[:, 1].reshape(xx.shape), 
                               cmap="PRGn", 
                               vmin = 0, 
                               vmax = 1)

axs[2][2].contourf(xx, yy, polytope_ids.reshape(xx.shape), cmap = "tab20", levels = len(np.unique(polytope_ids)))
axs[2][2].set_title("Estimated Partition", fontsize = 36)


y_hat = rfc.predict(X)
axs[3][0].scatter(X[:, 0], X[:, 1], c=['green' if y_hat[i] == 1 else 'purple' for i in range(len(y))],
          s=15, edgecolor = 'black', alpha = .25)
axs[3][0].set_title("Data Colored\nBy Estimated Class", fontsize = 36)
axs[3][0].set_ylabel("Random\nForest", fontsize = 36)

axs[3][1].set_title("Estimated Class\n1 Posterior", fontsize = 36)

estimated_class_1_posterior = rfc.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
axs[3][1].pcolormesh(xx, 
                               yy, 
                               estimated_class_1_posterior.reshape(xx.shape), 
                               cmap="PRGn", 
                               vmin = 0, 
                               vmax = 1)

predicted_leaf_ids_across_trees = np.array([tree.apply(np.c_[xx.ravel(), yy.ravel()]) for tree_idx, tree in enumerate(rfc.estimators_)])
#predicted_leaf_ids_across_trees = rfc.estimators_[0].apply(np.c_[xx.ravel(), yy.ravel()])
partition_ids = np.array([2 ** predicted_leaf_ids_across_trees[0, i] + 2 ** (predicted_leaf_ids_across_trees[1, i]) for i in range(np.shape(predicted_leaf_ids_across_trees)[1])])
#partition_ids = predicted_leaf_ids_across_trees

axs[3][2].contourf(xx, yy, partition_ids.reshape(xx.shape), cmap = "tab20", levels = len(np.unique(partition_ids)))
axs[3][2].set_title("Estimated Partition", fontsize = 36)

plt.show()

# %% [markdown]
# ## Keurnal Networks

# %%
X, y = generate_XOR(n = n)

# %%
second_layer_preactivations = np.matmul(X, input_weights) + input_bias 
second_layer_binary_activations = (second_layer_preactivations > 0).astype('int')
second_layer_activations = second_layer_preactivations * second_layer_binary_activations

ultimate_preactivations = np.matmul(second_layer_activations, ultimate_weights) + ultimate_bias
ultimate_binary_activations = (ultimate_preactivations > 0).astype('int')
ultimate_activations = ultimate_preactivations * ultimate_binary_activations

signed_second_layer_activations = (second_layer_activations > 0).astype('int')
signed_ultimate_activations = (ultimate_activations > 0).astype('int')

binary_activation = (network.predict(X) > 0.5).astype('int')

polytope_memberships = np.concatenate([signed_second_layer_activations, signed_ultimate_activations, binary_activation], axis = 1)
polytope_ids = np.array(np.matmul(polytope_memberships, 2 ** np.arange(0, np.shape(polytope_memberships)[1])))

polytope_id_to_posterior = {}
for polytope_id in np.unique(polytope_ids):
    posterior = []
    for y_val in np.unique(y):
        num_examples_of_polytope_of_class = len(np.where((polytope_ids == polytope_id) & (y == y_val))[0])
        posterior.append(num_examples_of_polytope_of_class)
    posterior = np.array(posterior) / np.sum(posterior)
    polytope_id_to_posterior[polytope_id] = posterior
'''
#an array of all of the X-values of the class-wise means in each leaf
polytope_means_X = []

#an array of all of the y-values (i.e. class values) of the class-wise means in each leaf
polytope_means_y = []

#an array of all of the number of points that comprise the means in each leaf
polytope_means_weight = []

#an array of all of the average variances of the points in each leaf corresponding to 
#a single class from the class-wise mean in that leaf
polytope_means_var = []

polytope_KDEs = []

for polytope_value in np.unique(polytope_ids):
    for y_val in np.unique(y):
        idxs_in_polytope_of_class = np.where((y == y_val) & (polytope_ids == polytope_value))[0]
        if len(idxs_in_polytope_of_class) > 1:
            mean_X_in_polytope_of_class = np.mean(X[idxs_in_polytope_of_class], axis = 0)
            polytope_means_X.append(mean_X_in_polytope_of_class)
            #we already know the y value, so just append it 
            polytope_means_y.append(y_val)
            #compute the number of points in that leaf corresponding to that y value
            #and append to the aggregate array
            polytope_means_weight.append(len(idxs_in_polytope_of_class))
            #compute the distances of all the points in that leaf corresponding to that y value
            #from the mean X-value of the points in that leaf corresponding to that y value
            dists_in_polytope = np.sqrt(np.sum((X[idxs_in_polytope_of_class] - mean_X_in_polytope_of_class)**2, axis = 1))
            #compute the variance as the average distance of the class-wise points in that leaf 
            #and append to the aggregate array
            polytope_means_var.append(np.mean(dists_in_polytope))
            


#convert to numpy array so we can easily refer to multiple sets of points as ra[idxs]
polytope_means_y, polytope_means_X, polytope_means_weight, polytope_means_var = np.array(polytope_means_y), np.array(polytope_means_X), np.array(polytope_means_weight), np.array(polytope_means_var)
#compute the bandwidth as the average variance across the class-wise leaf means, weighted
#by the number of points
bandwidth=np.average(polytope_means_var, weights = polytope_means_weight)

#an array of all of the KDEs. Each KDE will be respondsible for computing the probability 
#that a given set of inference points belongs to that class. Thus, we have separate KDEs 
#for each class. The KDE at index i is the KDE that is responsible for computations on 
#y_value = i
KDEs = []
#loop over the y values in the leaf means 
for y_val in np.unique(polytope_means_y):
    #gather all of the leaf means corresponding to the given y value
    polytope_means_X_of_y_val = polytope_means_X[np.where(polytope_means_y == y_val)[0]]
    #father all of the weights corresponding to the given y value
    polytope_means_weight_of_y_val = polytope_means_weight[np.where(polytope_means_y == y_val)[0]]
    #train an sklearn KDE with a gaussian kernel with the bandwidth calculated above
    polytope_means_var_of_y_val = polytope_means_var[np.where(polytope_means_y == y_val)[0]]
    bandwidth=np.average(polytope_means_var_of_y_val, weights = polytope_means_weight_of_y_val)
    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth)
    #fit the KDE on the leaf means corresponding to the given y value, weighted by
    #the weights corresponding to the given y value
    kde.fit(X = polytope_means_X_of_y_val, sample_weight = polytope_means_weight_of_y_val)

    #append the KDE to the aggregate array
    KDEs.append(kde)
'''
# Out:
# "\n#an array of all of the X-values of the class-wise means in each leaf\npolytope_means_X = []\n\n#an array of all of the y-values (i.e. class values) of the class-wise means in each leaf\npolytope_means_y = []\n\n#an array of all of the number of points that comprise the means in each leaf\npolytope_means_weight = []\n\n#an array of all of the average variances of the points in each leaf corresponding to \n#a single class from the class-wise mean in that leaf\npolytope_means_var = []\n\npolytope_KDEs = []\n\nfor polytope_value in np.unique(polytope_ids):\n    for y_val in np.unique(y):\n        idxs_in_polytope_of_class = np.where((y == y_val) & (polytope_ids == polytope_value))[0]\n        if len(idxs_in_polytope_of_class) > 1:\n            mean_X_in_polytope_of_class = np.mean(X[idxs_in_polytope_of_class], axis = 0)\n            polytope_means_X.append(mean_X_in_polytope_of_class)\n            #we already know the y value, so just append it \n            polytope_means_y.append(y_val)\n            #compute the number of points in that leaf corresponding to that y value\n            #and append to the aggregate array\n            polytope_means_weight.append(len(idxs_in_polytope_of_class))\n            #compute the distances of all the points in that leaf corresponding to that y value\n            #from the mean X-value of the points in that leaf corresponding to that y value\n            dists_in_polytope = np.sqrt(np.sum((X[idxs_in_polytope_of_class] - mean_X_in_polytope_of_class)**2, axis = 1))\n            #compute the variance as the average distance of the class-wise points in that leaf \n            #and append to the aggregate array\n            polytope_means_var.append(np.mean(dists_in_polytope))\n            \n\n\n#convert to numpy array so we can easily refer to multiple sets of points as ra[idxs]\npolytope_means_y, polytope_means_X, polytope_means_weight, polytope_means_var = np.array(polytope_means_y), np.array(polytope_means_X), np.array(polytope_means_weight), np.array(polytope_means_var)\n#compute the bandwidth as the average variance across the class-wise leaf means, weighted\n#by the number of points\nbandwidth=np.average(polytope_means_var, weights = polytope_means_weight)\n\n#an array of all of the KDEs. Each KDE will be respondsible for computing the probability \n#that a given set of inference points belongs to that class. Thus, we have separate KDEs \n#for each class. The KDE at index i is the KDE that is responsible for computations on \n#y_value = i\nKDEs = []\n#loop over the y values in the leaf means \nfor y_val in np.unique(polytope_means_y):\n    #gather all of the leaf means corresponding to the given y value\n    polytope_means_X_of_y_val = polytope_means_X[np.where(polytope_means_y == y_val)[0]]\n    #father all of the weights corresponding to the given y value\n    polytope_means_weight_of_y_val = polytope_means_weight[np.where(polytope_means_y == y_val)[0]]\n    #train an sklearn KDE with a gaussian kernel with the bandwidth calculated above\n    polytope_means_var_of_y_val = polytope_means_var[np.where(polytope_means_y == y_val)[0]]\n    bandwidth=np.average(polytope_means_var_of_y_val, weights = polytope_means_weight_of_y_val)\n    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth)\n    #fit the KDE on the leaf means corresponding to the given y value, weighted by\n    #the weights corresponding to the given y value\n    kde.fit(X = polytope_means_X_of_y_val, sample_weight = polytope_means_weight_of_y_val)\n\n    #append the KDE to the aggregate array\n    KDEs.append(kde)\n"

# %%
figs, axs = plt.subplots(2, 2, figsize = (20, 20))
figs.text(0.5, 0.04, '', ha='center')
figs.set_facecolor('white')

for i, ax in enumerate(axs.flat):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.label_outer()
    ax.set_facecolor('white')
    
    for side in {"right", "left", "top", "bottom"}:
        ax.spines[side].set_visible(False)
    
second_layer_preactivations = np.matmul(np.c_[xx.ravel(), yy.ravel()], input_weights) + input_bias 
second_layer_binary_activations = (second_layer_preactivations > 0).astype('int')
second_layer_activations = second_layer_preactivations * second_layer_binary_activations

ultimate_preactivations = np.matmul(second_layer_activations, ultimate_weights) + ultimate_bias
ultimate_binary_activations = (ultimate_preactivations > 0).astype('int')
ultimate_activations = ultimate_preactivations * ultimate_binary_activations

signed_second_layer_activations = (second_layer_activations > 0).astype('int')
signed_ultimate_activations = (ultimate_activations > 0).astype('int')

binary_activation = (network.predict(np.c_[xx.ravel(), yy.ravel()]) > 0.5).astype('int')

polytope_memberships = np.concatenate([signed_second_layer_activations, signed_ultimate_activations, binary_activation], axis = 1)
polytope_ids = np.array(np.matmul(polytope_memberships, 2 ** np.arange(0, np.shape(polytope_memberships)[1])))
    
y_proba = np.array([polytope_id_to_posterior[polytope_id] if polytope_id in list(polytope_id_to_posterior.keys()) else [0.5, 0.5] for polytope_id in polytope_ids])

#loops over the KDEs (and thus, implicitly, the y-values)
for y_val in range(2):
    #compute the (unnormalized) posterior for the KDE corresponding
    #to y_val. NOTE: we perform np.exp since the score_samples 
    #function returns the log of the probability of belonging to that 
    #class, so we must invert the log through an exponential
    
    for i in range(2):
        figs.colorbar(axs[i][y_val].pcolormesh(xx, 
               yy,          
               y_proba[:, y_val].reshape(xx.shape),
               cmap = "Reds" if y_val == 1 else "Blues"),
                 ax = axs[i][y_val])
    '''
    axs[0][y_val].scatter(polytope_means_X[:, 0], polytope_means_X[:, 1], c = 2 * polytope_means_y - 1, s = 1000 * np.array(polytope_means_weight) / np.max(polytope_means_weight), edgecolor = 'black', cmap = "seismic")
    axs[0][y_val].set_title("Polytope Means\n(Size Indicates Weight,\nColor Indicates Class)", fontsize = 25)
    '''
        
for y_val in range(2):
    idxs_of_class = np.where(y == y_val)
    axs[1][y_val].set_title("Points Of Class {}".format(y_val), fontsize = 25)
    axs[1][y_val].scatter(X[idxs_of_class, 0], X[idxs_of_class, 1], c = 'black', alpha = .1)
    
figs.suptitle("Estimated (Unnormalized) Posteriors")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import matplotlib.cm as cm

fig = plt.figure(figsize = (36, 12))
ax = fig.add_subplot(131, projection='3d')

ax.plot_surface(xx, yy, (y_proba[:, 1] / np.sum(y_proba, axis = 1)).reshape(xx.shape), linewidth=0, antialiased=False, cmap = "Greens")
ax.set_zlim(0, 1)
#ax.set_zlabel('KDN Estimated Posterior')
ax.set_zlabel('UN Estimated Posterior', fontsize = 24)

ax = fig.add_subplot(132, projection='3d')

ax.plot_surface(xx, yy, np.array(true_posterior).reshape(xx.shape), linewidth=0, antialiased=False, cmap = "Greens")
ax.set_zlim(0, 1)
ax.set_zlabel('True Posterior', fontsize = 24)

ax = fig.add_subplot(133, projection='3d')

surface = ax.plot_surface(xx, yy, np.abs(np.array(true_posterior) - y_proba[:, 1] / np.sum(y_proba, axis = 1)).reshape(xx.shape), linewidth=0, antialiased=False, cmap = "Greens")
ax.set_zlim(0, 1)
ax.set_zlabel('Absolute Difference', fontsize = 24)

fig.colorbar(surface)

plt.show()
plt.close()
