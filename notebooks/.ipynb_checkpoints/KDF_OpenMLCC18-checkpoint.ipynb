# %%
import keras
import numpy as np

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 6

from sklearn.neighbors import KernelDensity
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier

from tqdm.notebook import tqdm

from scipy import stats

from sklearn import datasets

import sys 
sys.path.append("../")
from KDG import KDG

import openml
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Experiment Parameters

# %%
max_depth = 10
n_estimators = 2
num_trials = 50

# %% [markdown]
# # Data Generation

# %% [markdown]
# # Construct & Train Network

# %% [markdown]
# ## Keurnal Networks

# %%
def train_AKN(X, y):
    X_transform, X, y_transform, y = train_test_split(X, y, test_size = .9)
    #X_transform, y_transform = X, y
    rfc = RandomForestClassifier(n_estimators = n_estimators, 
                                   max_depth = max_depth)

    rfc.fit(X, y)

    predicted_leaf_ids_across_trees = [np.unique(tree.apply(X), return_inverse = True)[1] for tree_idx, tree in enumerate(rfc.estimators_)]

    return KDG().fit(X, y, predicted_leaf_ids_across_trees)

# %%
def get_ece(predicted_posterior, y):
    hists = []
    hists_hat = []
    amts = []
    num_bins = 40
    eces_across_y_vals = []
    for y_val in np.unique(y):
        for i in range(num_bins):
            prop = i*1./num_bins
            inds = np.where((predicted_posterior[:, y_val] >= prop) & (predicted_posterior[:, y_val] <= prop+1./num_bins))[0]
            amts.append(len(inds))
            if len(inds) > 0:
                hists.append(len(np.where(y[inds] == y_val)[0])*1./len(inds))
                hists_hat.append(np.mean(predicted_posterior[inds, y_val]))
            else:
                hists.append(prop)
                hists_hat.append(prop + 0.5/num_bins)
        eces_across_y_vals.append(np.dot(np.abs(np.array(hists) - np.array(hists_hat)), amts) / np.sum(amts))
        return np.mean(eces_across_y_vals)

# %%
def get_brier(predicted_posterior, y):
    brier_across_y_vals = []
    for y_val in np.unique(y):
        brier_across_y_vals.append(np.nanmean((predicted_posterior[:, y_val] - (y == y_val).astype('int'))**2))
    return np.mean(brier_across_y_vals)

# %%
def get_network_y_proba(X, y, n, X_test):
    random_indices = np.random.choice(len(X), int(n), replace = False)
    X, y = X[random_indices], y[random_indices]
    rfc = RandomForestClassifier(n_estimators = n_estimators, 
                                   max_depth = max_depth)

    rfc.fit(X, y)
    return rfc.predict_proba(X_test)
    

def get_KDE_y_proba(X, y, n, X_test):
    random_indices = np.random.choice(len(X), int(n), replace = False)
    X, y = X[random_indices], y[random_indices]
    kdg = train_AKN(X, y)
    y_proba_unnormalized = kdg.predict_proba(X_test, pooling = "polytope")

    y_proba = y_proba_unnormalized.copy()
    for y_val in range(np.shape(y_proba)[1]):
        y_proba[:, y_val] /= np.sum(y_proba_unnormalized, axis = 1)
        
    return y_proba

# %%
def clipped_mean(ra, low = 25, high = 75):
    ra = np.array(ra)
    lower_val = np.nanpercentile(ra, low)
    higher_val = np.nanpercentile(ra, high)
    return np.mean(ra[np.where((ra >= lower_val) & (ra <= higher_val))[0]])

# %%
end_brier_ratio_across_dataset_idx = []
end_generalization_error_ratio_across_dataset_idx = []
for dataset_idx in range(72):
    successfully_loaded = True
    try:
        X, y = openml.tasks.get_task(dataset_idx).get_X_and_y()
    except:
        print("Skipping Dataset {}".format(dataset_idx))
        successfully_loaded = False
    
    if successfully_loaded:
        is_categorical = False
        for feat in range(np.shape(X)[1]):
            if len(np.unique(X[:, feat])) < len(X):
                is_categorical = True
        print("Categorical = {}".format(is_categorical))
        print("Dataset Num = {}".format(dataset_idx))
        print("N = {}".format(len(X)))
        print("D = {}".format(np.shape(X)[1]))
        print()
        kappa_acc_means = []
        kappa_acc_stds = []

        kappa_brier_means = []
        kappa_brier_stds = []
        
        if len(X) > 10 / .7 and is_categorical:
            n_ra = np.logspace(1, np.log10(len(X) * 0.7), num = 5, base = 10)
            for n in tqdm(n_ra):
                kappa_acc_across_trials = []
                kappa_brier_across_trials = []
                for trial_idx in range(num_trials):
                    try:
                        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.7)
                        counts = np.bincount(y_test)
                        max_class_frequency = np.max(counts)
                        bayes_error = max_class_frequency / len(y_test)

                        KDE_y_proba = get_KDE_y_proba(X_train, y_train, n, X_test)
                        network_y_proba = get_network_y_proba(X, y, n, X_test)

                        KDE_acc = (bayes_error + 1e-12) / (np.mean(np.argmax(KDE_y_proba, axis = 1) != y_test) + 1e-12)
                        network_acc = (bayes_error + 1e-12) / (np.mean(np.argmax(network_y_proba, axis = 1) != y_test) + 1e-12)

                        KDE_brier = (.25 + 1e-12)  / (get_brier(KDE_y_proba, y_test) + 1e-12)
                        network_brier = (.25 + 1e-12) / (get_brier(network_y_proba, y_test) + 1e-12)

                        kappa_acc_across_trials.append(KDE_acc - network_acc)
                        kappa_brier_across_trials.append(KDE_brier - network_brier)
                    except:
                        pass
                if len(kappa_acc_across_trials) > 0 and len(kappa_brier_across_trials) > 0:
                    kappa_acc_means.append(np.mean(kappa_acc_across_trials))
                    kappa_acc_stds.append(np.std(kappa_acc_across_trials))

                    kappa_brier_means.append(np.mean(kappa_brier_across_trials))
                    kappa_brier_stds.append(np.std(kappa_brier_across_trials))

                    end_brier_ratio_across_dataset_idx.append(kappa_brier_means[-1])
                    end_generalization_error_ratio_across_dataset_idx.append(kappa_acc_means[-1])
            
            if len(kappa_acc_means) > 1 and len(kappa_brier_means) > 1:
                figs, ax = plt.subplots(1, 2, figsize = (18, 9))
                figs.set_facecolor("white")

                ax[0].tick_params(axis='both', which='major', labelsize=27)
                ax[0].plot(n_ra[:len(kappa_acc_means)], kappa_acc_means)
                ax[0].hlines(0.0, 0, np.max(n_ra[:len(kappa_acc_means)]), linestyle = "dashed", label = "Perfect", color = "black")
                ax[0].legend(fontsize = 18, loc = "upper right", frameon = False)
                ax[0].set_xlabel("Number of Training Samples (logscale)", fontsize = 27)
                ax[0].set_ylabel("Kappa (Generalization Error)", fontsize = 27)
                ax[0].set_xscale("log")
                ax[0].fill_between(n_ra[:len(kappa_acc_means)], 
                               np.array(kappa_acc_means) + np.array(kappa_acc_stds),
                               np.array(kappa_acc_means) - np.array(kappa_acc_stds),
                               alpha = .1,
                               color = "blue")
                for side in {"right", "top"}:
                        ax[0].spines[side].set_visible(False)

                ax[1].tick_params(axis='both', which='major', labelsize=27)
                ax[1].plot(n_ra[:len(kappa_brier_means)], kappa_brier_means)
                ax[1].hlines(0.0, 0, np.max(n_ra[:len(kappa_brier_means)]), linestyle = "dashed", color = "black")
                ax[1].set_xlabel("Number of Training Samples (logscale)", fontsize = 27)
                ax[1].set_ylabel("Kappa (Brier Score)", fontsize = 27)
                ax[1].set_xscale("log")
                ax[1].fill_between(n_ra[:len(kappa_brier_means)], 
                               np.array(kappa_brier_means) + np.array(kappa_brier_stds),
                               np.array(kappa_brier_means) - np.array(kappa_brier_stds),
                               alpha = .1,
                               color = "blue")
                for side in {"right", "top"}:
                        ax[1].spines[side].set_visible(False)

                figs.tight_layout()

                plt.show()
        else:
            print("Dataset Has Fewer Than 100 Samples")
# Out:
# Skipping Dataset 0
# Categorical = True
# Dataset Num = 1
# N = 898
# D = 38
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Categorical = True
# Dataset Num = 2
# N = 898
# D = 38
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Categorical = True
# Dataset Num = 3
# N = 3196
# D = 36
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Categorical = True
# Dataset Num = 4
# N = 57
# D = 16
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Categorical = True
# Dataset Num = 5
# N = 452
# D = 279
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Categorical = True
# Dataset Num = 6
# N = 20000
# D = 16
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
figs, ax = plt.subplots(1, 2, figsize = (12, 6))
end_brier_ratio_across_dataset_idx = np.array(end_brier_ratio_across_dataset_idx)
end_generalization_error_ratio_across_dataset_idx = np.array(end_generalization_error_ratio_across_dataset_idx)

finite_idxs = np.where(~np.isnan(end_generalization_error_ratio_across_dataset_idx) & ~np.isinf(end_generalization_error_ratio_across_dataset_idx) & (end_generalization_error_ratio_across_dataset_idx < 1e3) & (end_generalization_error_ratio_across_dataset_idx > 0) & ~np.isnan(end_brier_ratio_across_dataset_idx) & ~np.isinf(end_brier_ratio_across_dataset_idx) & (end_brier_ratio_across_dataset_idx < 1e3) & (end_brier_ratio_across_dataset_idx > 0))[0]
ax[0].boxplot(end_generalization_error_ratio_across_dataset_idx[finite_idxs], widths = 1)
ax[0].set_yticklabels([-50, -25, 0, 25, 50], fontsize = 16)
ax[0].set_yticks([-50, -25, 0, 25, 50])
ax[0].set_ylim((-50, 50))
ax[0].hlines(0.0, 0, 2, linewidth = 1, color = "green")
ax[0].set_xticks([])
ax[0].set_ylabel("Generalization Error", fontsize = 16)

ax[1].boxplot(end_brier_ratio_across_dataset_idx[finite_idxs], widths = 1)
ax[1].set_yticklabels([-50, -25, 0, 25, 50], fontsize = 16)
ax[1].set_yticks([-50, -25, 0, 25, 50])
ax[1].set_ylim((-50, 50))
ax[1].hlines(0.0, 0, 2, linewidth = 1, color = "green")
ax[1].set_xticks([])
ax[1].set_ylabel("Brier Score", fontsize = 16)

figs.suptitle("Kappa Difference (KDE - RF)", fontsize = 16)
# Out:
# Text(0.5, 0.98, 'Kappa Difference (KDE - RF)')
